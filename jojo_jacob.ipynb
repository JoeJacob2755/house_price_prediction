# %% [markdown]
# ## **IIT-B & UpGrad**
#
# ### Assignmnet-2

# %% [markdown]
# ### Table of Contents
# ### Table of Contents
# - 1. [Introduction](#section1)<br>
# - 2. [Bussiness Goal](#section2)<br>
# - 3. [Project Approch](#section3)<br>
# - 4. [Importing Libraries and Functions](#section4)<br>
#   - 4.1. [Import Libraries](#section41)<br>
#   - 4.2. [Importing Libraries and Functions](#section42)<br>
# - 5. [Data Preperation](#section5)<br>
#   - 5.1. [Load Data](#section51)<br>
#   - 5.2. [Split Data](#section52)<br>
#   - 5.3. [Data Handling](#section53)<br>
#     - 5.3.1. [Data Handling: Missing Values](#section531)<br>
#     - 5.3.2. [Data Handling: Unique Values](#section532)<br>
#     - 5.3.3. [Data Handling: Duplicate Values](#section533)<br>
#     - 5.3.4. [Data Handling: Data Types](#section534)<br>
#   - 5.4. [Outlier Detection and Elimination](#section54)<br>
#   - 5.5. [Feature Engineering](#section55)<br>
#   - 5.6. [Correlation Detection](#section56)<br>
# - 6. [Exploratory Data Analysis](#section6)<br>
#   - 6.1. [Analysis of Traget Variable: Sale Price](#section61)<br>
#   - 6.2. [Univariate Analysis](#section62)<br>
#   - 6.3. [Univariate Analysis](#section63)<br>
#     - 6.3.1. [Biivariate Analysis: Numerical Vriables](#section631)<br>
#     - 6.3.2. [Biivariate Analysis: Categorical Vriables](#section631)<br>
# - 7. [Model Creation](#section7)<br>
#   - 7.1. [Seperating X and Y of train Data](#section71)<br>
#   - 7.2. [Scaling of Numeric Variable](#section72)<br>
#   - 7.3. [Create Dummy Variables](#section73)<br>
#   - 7.4. [Recursive Feature Elimination - 1](#section74)<br>
#   - 7.5. [Create Models](#section75)<br>
#     - 7.5.1. [Model - 1](#section751)<br>
#     - 7.5.2. [Model - 2](#section752)<br>
#     - 7.5.3. [Model - 3](#section753)<br>
#     - 7.5.4. [Model - 4](#section754)<br>
#   - 7.6 [Second RFE Slection](#section76)<br>
#     - 7.6.1. [Model - 5](#section761)<br>
#     - 7.6.2. [Model - 6](#section762)<br>
#     - 7.6.3. [Model - 7](#section763)<br>
#     - 7.6.4. [Model - 8](#section764)<br>
#     - 7.6.5. [Model - 9](#section765)<br>
#     - 7.6.6. [Model - 10](#section766)<br>
#     - 7.6.7. [Model - 11](#section767)<br>
#     - 7.6.8. [Model - 12](#section768)<br>
#     - 7.6.9. [Model - 13](#section769)<br>
#     - 7.6.10.[Model - 14](#section7610)<br>
#     - 7.6.11.[Model - 15](#section7611)<br>
#     - 7.6.12.[Model - 16](#section7612)<br>
#   - 7.8.[Ridge and Lasso Regression](#section78)<br>
#     - 7.8.1. [Ridge Regression](#section781)<br>
#       - 7.8.1.1. [Fit Ridge Model using Best Lambda Value](#section7811)<br>
#       - 7.8.1.2. [Predict Target Value on Train Data](#section7812)<br>
#     - 7.8.2. [Lasso Regression](#section782)<br>
#       - 7.8.2.1. [Fit Lasso Model using Best Lambda Value](#section7821)<br>
#       - 7.8.2.2. [Predict Target Value on Train Data](#section7822)<br>
# - 8. [Prepare Test Data](#section8)<br>
#   - 8.1. [Adjusting Difference in Variable Count](#section81)<br>
# - 9. [Model Evaluation](#section9)<br>
# - 10. [Conclusion](#section10)<br>
#   - 10.1. [Summary](#section101)<br>
#   - 10.2. [Recoomendation](#section102)<br>
#   - 10.3. [Acknowledgement](#section103)<br>

# %% [markdown]
# ### 1. Intoduction<a class="anchor" id="section1"></a>
#
# - A US-based housing company named Surprise Housing has decided to enter the Australian market. The company uses data analytics to purchase houses at a price below their actual values and flip them on at a higher price. For the same purpose, the company has collected a data set from the sale of houses in Australia. The data is provided in the CSV file below.
# - The company is looking at prospective properties to buy to enter the market. You are required to build a regression model using regularisation in order to predict the actual value of the prospective properties and decide whether to invest in them or not.

# %% [markdown]
# ### 2. Bussiness Goal<a class="anchor" id="section2"></a>
# - Model the price of houses with the available independent variables.
# - This model will then be used by the management to understand how exactly the prices vary with the variables.
# - Model should help manipulate the strategy of the firm and concentrate on areas that will yield high returns.
# - Further, the model will be a good way for management to understand the pricing dynamics of a new market.
#
# - **The company wants to know:**
#   - Which variables are significant in predicting the price of a house.
#   - How well those variables describe the price of a house.

# %% [markdown]
# ### 3. Project Approach<a class="anchor" id="section3"></a>
# - Import libraries
# - Define functions
# - Data Preperation
#   - Data Cleaning
#     - Dealing with missing variables
#     - Dealing with unique values
#     - Dealing with duplicate values
#     - Dealing with data types of variables.
#   - Outlier detection
#       - Identifying outliers
#       - Managing outliers
# - EDA
#  - Univariate Analysis
#  - Bivariate Analysis
#     - Numerical variables analysis
#     - Categorical variable analysis
# - Model Creation
#   - Data Transformation
#     - Scaling
#     - Creating Dummy Variables
#   - Creating Regression Model
#     - RFE to select important variables
#     - VIF to remove correlation between indepedent variables
#     - Select best variables
#   - Use Ridge and Lasso Regression
#   - Evaluation and model selection
# - Prepare Test Data
# - Use selected model for prediction on test data
# - Final Evaluation
# - Conclusion
#   - Summary
#   - Recommendation

# %% [markdown]
# ### 4. Import Libraries & Define Functions<a class="anchor" id="section4"></a>

# %% [markdown]
# #### 4.1. Import Libraries<a class="anchor" id="section41"></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import statsmodels
import statsmodels.api as sm
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression # LinearRegresion is a class as L and R are in upper case
from sklearn.preprocessing import MinMaxScaler as MinMax
from sklearn.preprocessing import StandardScaler as sc

import statsmodels.api as sm
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.feature_selection import RFE
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ##### 4.2. Define Functions<a class="anchor" id="section42"></a>

# %%
# This function will retun a data frame with missing values and its percentage

def missing_data(data):
    total = data.isna().sum()[data.isna().sum() != 0]
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    if [missing_df['Total'] == 0]:
        missing_df.dropna(axis=0, inplace = True)
    return missing_df

# %%
# Function to check unique values in columns
def col_unique_value_check(x,colname):
  print("Number of unique values are : ", x[colname].nunique(), '\n')
  print("Value Counts", '\n', x[colname].value_counts(),'\n')
  numbers = x[colname].isnull().sum()
  missing_percent = (x[colname].isnull().sum()/len(x[colname])*100)
  print('Number of unique of value in {} is {} & percentage is {} %'.format(colname, numbers, round(missing_percent,3)))
  return

# %%
# Function to drop columns based on thereshold of missing values
def drop_missing_value_col(x,thershold):
  drop_cols = (x.isnull().sum()/len(x))
  drop_cols = list(drop_cols[drop_cols.values >= thershold].index)
  print("No of cols to be dropped :",len(drop_cols))    
  print(drop_cols)
  x.drop(labels = drop_cols,axis =1, inplace = True)     
  print(x.shape)
  return

# %%
# Function to impute missing values
def impute_values(x):
  missing_cols = [c for c in
                  x.columns
                  if x[c].isnull().sum()>0]
  int_col = [i for i in missing_cols
             if x[i].dtype == 'float64']
  str_col = [i for i in missing_cols
             if x[i].dtype == 'object' ]   
     # x[c] = x[c].fillna[x[c].median(), inplace = True]
  print(int_col)
  print(str_col)
  for c in x.columns:
    if x[c].isnull().sum()>0:
      if x[c].dtype == 'float64':
        x[c].fillna(x[c].median(), inplace=True)
      elif x[c].dtype == 'int':
        x[c].fillna(x[c].median(), inplace=True)
      elif x[c].dtype == 'object':
        x[c].fillna(x[c].mode()[0], inplace=True)

# %%
# Function to create charts for categorical variables
# Count plots and box plots aganist variable and sales price
def cat_chart(var1,var2, label_rotation):
  f, ax = plt.subplots(2,2, figsize=(12,10))
  f.subplots_adjust(hspace=0.5, wspace=0.5)

  sns.countplot(data=h_train, x=h_train[var1], palette ='rainbow',  ax=ax[0,0])
  sns.boxplot(x=h_train[var1], y=h_train.SalePrice, palette=('husl'), ax= ax[0,1])
  ax[0,0].set_title(label = 'Count Plot of '+ var1, size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  ax[0,0].set_xlabel(xlabel = '%s'%var1, size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  ax[0,0].set_ylabel(ylabel = 'Count of '+ '%s'%var1, size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  if(label_rotation):
        ax[0,0].set_xticklabels(ax[0,0].get_xticklabels(),rotation=90)

  ax[0,1].set_title(label = 'Price Vs '+ var1, size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  ax[0,1].set_xlabel(xlabel = '%s'%var1, size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  ax[0,1].set_ylabel(ylabel = 'Sale Price', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  if(label_rotation):
        ax[0,1].set_xticklabels(ax[0,1].get_xticklabels(),rotation=90)

  ax[0,0].tick_params(axis="x", labelsize=14, labelcolor="purple" )
  ax[0,1].tick_params(axis="x", labelsize=14, labelcolor="purple")


  sns.countplot(data=h_train, x=h_train[var2], palette ='rainbow',  ax=ax[1,0])
  sns.boxplot(x=h_train[var2], y=h_train.SalePrice, palette=('husl'), ax= ax[1,1])
  ax[1,0].set_title(label = 'Count Plot of '+ var2, size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  ax[1,0].set_xlabel(xlabel = '%s'%var2, size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  ax[1,0].set_ylabel(ylabel = 'Count of '+ '%s'%var2, size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  if(label_rotation):
        ax[1,0].set_xticklabels(ax[1,0].get_xticklabels(),rotation=90)

  ax[1,1].set_title(label = 'Price Vs '+ var2, size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  ax[1,1].set_xlabel(xlabel = '%s'%var2, size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  ax[1,1].set_ylabel(ylabel = 'Sale Price', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
  if(label_rotation):
        ax[1,1].set_xticklabels(ax[1,1].get_xticklabels(),rotation=90)
  
  ax[1,0].tick_params(axis="x", labelsize=14, labelcolor="purple")
  ax[1,1].tick_params(axis="x", labelsize=14, labelcolor="purple")

# %%
def pair_p(w,x,y,z):
    sns.pairplot(h_train, x_vars=[w,x,y,z], y_vars='SalePrice',height=4, aspect=1, kind='scatter')
    plt.show()

# %% [markdown]
# ### 5. Data Preperation<a class="anchor" id="section5"></a>

# %% [markdown]
# #### 5.1 Load Data<a class="anchor" id="section51"></a>
# - Source is as given in the problem statement by IIT B/UpGrad

# %%
# load data
house_raw = pd.read_csv('https://ml-course3-upgrad.s3.amazonaws.com/Assignment_+Advanced+Regression/train.csv')
house_raw.shape
# Out:
# (1460, 81)

# %%
house_raw.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# #### 5.2 Split Data<a class="anchor" id="section52"></a>
# - Split the data into train and test set.
# - This is done at the very begining to simulate real world condition where test data is not avalable.
# - Train Test ration is set at 70:30
# - Train set is called **h_train**
# - Test set is called **h_test**

# %%
# split data
h_train, h_test = train_test_split(house_raw,test_size=0.3, random_state = 2)

# %%
print('train data shape: ', h_train.shape)
print('test data shape : ', h_test.shape)
# Out:
# train data shape:  (1022, 81)
# test data shape :  (438, 81)

# %%
h_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1022 entries, 104 to 1192
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1022 non-null   int64
#  1   MSSubClass     1022 non-null   int64
#  2   MSZoning       1022 non-null   object
#  3   LotFrontage    847 non-null    float64
#  4   LotArea        1022 non-null   int64
#  5   Street         1022 non-null   object
#  6   Alley          68 non-null     object
#  7   LotShape       1022 non-null   object
#  8   LandContour    1022 non-null   object
#  9   Utilities      1022 non-null   object
#  10  LotConfig      1022 non-null   object
#  11  LandSlope      1022 non-null   object
#  12  Neighborhood   1022 non-null   object
#  13  Condition1     1022 non-null   object
#  14  Condition2     1022 non-null   object
#  15  BldgType       1022 non-null   object
#  16  HouseStyle     1022 non-null   object
# ...

# %% [markdown]
# #### Initial Observations
# - There are 1460 rows and 81 columns
# - Train set as 1022, ie 70% of data
# - Test set as 438 rows ie 30% of data

# %% [markdown]
# #### 5.3. Data Handling<a class="anchor" id="section53"></a>
# - Missing Data
# - Unique Values
# - Duplicate Values
# - Data Types
# - Redundant Data

# %% [markdown]
# #### 5.3.1 Data Handling: Missing Values<a class="anchor" id="section53"></a>
# - Threshold set at 30%
# - Variables with missing values more than threshold will be deleted
# - Variables with missing values less than threshold will be imputed

# %%
# Find missing Data
missing_data(h_train)
# Out:
#                Total    Percent
# LotFrontage    175.0  17.123288
# Alley          954.0  93.346380
# MasVnrType       6.0   0.587084
# MasVnrArea       6.0   0.587084
# BsmtQual        26.0   2.544031
# BsmtCond        26.0   2.544031
# BsmtExposure    27.0   2.641879
# BsmtFinType1    26.0   2.544031
# BsmtFinType2    26.0   2.544031
# Electrical       1.0   0.097847
# FireplaceQu    497.0  48.630137
# GarageType      58.0   5.675147
# GarageYrBlt     58.0   5.675147
# GarageFinish    58.0   5.675147
# GarageQual      58.0   5.675147
# GarageCond      58.0   5.675147
# PoolQC        1020.0  99.804305
# Fence          821.0  80.332681
# MiscFeature    979.0  95.792564

# %%
# visualize missing data
plt.figure(figsize=(18,8))
h_train.isna().sum().plot.bar()
plt.show()

# %%
drop_missing_value_col(h_train,.3)
# Out:
# No of cols to be dropped : 5
# ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']
# (1022, 76)

# %%
missing_data(h_train)
# Out:
#               Total    Percent
# LotFrontage   175.0  17.123288
# MasVnrType      6.0   0.587084
# MasVnrArea      6.0   0.587084
# BsmtQual       26.0   2.544031
# BsmtCond       26.0   2.544031
# BsmtExposure   27.0   2.641879
# BsmtFinType1   26.0   2.544031
# BsmtFinType2   26.0   2.544031
# Electrical      1.0   0.097847
# GarageType     58.0   5.675147
# GarageYrBlt    58.0   5.675147
# GarageFinish   58.0   5.675147
# GarageQual     58.0   5.675147
# GarageCond     58.0   5.675147

# %%
impute_values(h_train)
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
# ['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']

# %%
missing_data(h_train)
# Out:
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %% [markdown]
# #### Observations: Missing Values
# - Columns 'Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature' have more than threshold (30%) missing values. Hence they will be dropped
# - Balance of the variables with missing values will be imputed:
#   - Categorical variables will be imputed by mode
#   - Numerical variables will be imputed using median.
# - Columns with less than 30%
#   - Categorical Columns: LotFrontage, MasVnrArea, GarageYrBlt
#   - Numerical Columns  : MasVnrType, BsmtQual, BsmtCond, BsmtExposure, BsmtExposure, BsmtFinType1, BsmtFinType2, Electrical, GarageType, GarageFinish, GarageQual, GarageCond

# %% [markdown]
# #### 5.3.2. Data Handling: Unique Values in variables<a class="anchor" id="section532"></a>
# - If the number of unique values is one or
# - If the percentage of unique values is highly skwed towards one value
# - Then the variable is of no significance to the anaylisis.
# - Such variables will be deleted

# %%
#  Finding Unique Values
h_train.nunique().sort_values()
# Out:
# Utilities          2
# CentralAir         2
# Street             2
# BsmtHalfBath       3
# GarageFinish       3
#                 ...
# 1stFlrSF         611
# BsmtUnfSF        627
# GrLivArea        671
# LotArea          782
# Id              1022
# Length: 76, dtype: int64

# %% [markdown]
# #### Observations: Unique Values
# - There are no valriables with one value or values with skewed percentages.
# - However, if such occurances are noticed in future, the varialble will be deleted.

# %% [markdown]
# #### 5.3.3. Data Handling : Duplicate Values<a class="anchor" id="section533"></a>
# - Duplicate rows or columns if any will be deleted

# %%
# duplicate values
duplicates = h_train[h_train.duplicated()]
duplicates.shape
# Out:
# (0, 76)

# %% [markdown]
# #### Observations: Dulplicate Values
# - No duplicate values found

# %% [markdown]
# #### 5.3.4. Data Handling:  Data Types<a class="anchor" id="section534"></a>
# - Conversion of Numerical representation of categories
# - Conversion and extratcion of dates

# %%
h_train['MSSubClass'] = h_train['MSSubClass'].astype('str')

# %% [markdown]
# #### Observations: Data types
# - Only MSSubClass needed conversion fron numeric to categorical data types.
# - Years and months did not need conversion

# %% [markdown]
# #### 5.4. Outlier Detection and Elimination<a class="anchor" id="section54"></a>
# - Use describe() and box plots to find outliers
# - Analyse each outlier column to gain more insight
# - In case of outliers remove those above .95 percentage using IQR

# %%
# Use describe() to analyse numerical values
h_test.describe().T
# Out:
#                count           mean           std      min        25%  \
# Id             438.0     740.552511    424.011604      3.0     372.00
# MSSubClass     438.0      55.913242     41.567807     20.0      20.00
# LotFrontage    354.0      70.093220     24.704825     21.0      59.00
# LotArea        438.0   10822.568493   9623.758896   1300.0    7801.00
# OverallQual    438.0       6.210046      1.383687      3.0       5.00
# OverallCond    438.0       5.557078      1.076133      2.0       5.00
# YearBuilt      438.0    1973.363014     29.464763   1885.0    1957.00
# YearRemodAdd   438.0    1985.698630     20.462402   1950.0    1968.00
# MasVnrArea     436.0     114.676606    193.709175      0.0       0.00
# BsmtFinSF1     438.0     452.324201    503.178942      0.0       0.00
# BsmtFinSF2     438.0      48.068493    158.571108      0.0       0.00
# BsmtUnfSF      438.0     596.707763    466.851111      0.0     244.50
# ...

# %%
# Use Box plots to visualize outliers
f, ax = plt.subplots(2,3, figsize=(20,10))

sns.boxplot(y="LotFrontage", data=h_train, ax = ax[0,0])
sns.boxplot(y="LotArea", data=h_train, ax = ax[0,1])
sns.boxplot(y="MasVnrArea", data=h_train, ax = ax[0,2])
sns.boxplot(y="BsmtFinSF1", data=h_train, ax = ax[1,0])
sns.boxplot(y="BsmtUnfSF", data=h_train, ax = ax[1,1])
sns.boxplot(y="BsmtFinSF2", data=h_train, ax = ax[1,2])

# %%
f, ax = plt.subplots(2,3, figsize=(20,10))

sns.boxplot(y="1stFlrSF", data=h_train, ax = ax[0,0])
sns.boxplot(y="2ndFlrSF", data=h_train, ax = ax[0,1])
sns.boxplot(y="LowQualFinSF", data=h_train, ax = ax[0,2])
sns.boxplot(y="GrLivArea", data=h_train, ax = ax[1,0])
sns.boxplot(y="GarageArea", data=h_train, ax = ax[1,1])
sns.boxplot(y="WoodDeckSF", data=h_train, ax = ax[1,2])

# %%
f, ax = plt.subplots(2,3, figsize=(20,10))

sns.boxplot(y="WoodDeckSF", data=h_train, ax = ax[0,0])
sns.boxplot(y="OpenPorchSF", data=h_train, ax = ax[0,1])
sns.boxplot(y="EnclosedPorch", data=h_train, ax = ax[0,2])
sns.boxplot(y="3SsnPorch", data=h_train, ax = ax[1,0])
sns.boxplot(y="ScreenPorch", data=h_train, ax = ax[1,1])
sns.boxplot(y="PoolArea", data=h_train, ax = ax[1,2])

# %% [markdown]
# #### Analysing each column with outlier values

# %%
h_train['3SsnPorch'].value_counts()
# Delete the column
# Out:
# 0      1003
# 144       2
# 168       2
# 216       2
# 407       1
# 320       1
# 162       1
# 182       1
# 290       1
# 96        1
# 304       1
# 153       1
# 245       1
# 238       1
# 508       1
# 130       1
# 140       1
# Name: 3SsnPorch, dtype: int64

# %%
h_train['PoolArea'].value_counts()
# Out:
# 0      1020
# 576       1
# 555       1
# Name: PoolArea, dtype: int64

# %%
h_train['BsmtFinSF2'].nunique()
# Out:
# 101

# %%
h_train['LowQualFinSF'].value_counts()
# Out:
# 0      1000
# 80        3
# 397       1
# 205       1
# 515       1
# 473       1
# 144       1
# 53        1
# 513       1
# 528       1
# 514       1
# 120       1
# 384       1
# 371       1
# 234       1
# 481       1
# 232       1
# 156       1
# 420       1
# 479       1
# 360       1
# Name: LowQualFinSF, dtype: int64

# %%
h_train['WoodDeckSF'].value_counts()
# Out:
# 0      542
# 192     23
# 100     22
# 120     22
# 168     19
#       ...
# 195      1
# 392      1
# 361      1
# 110      1
# 126      1
# Name: WoodDeckSF, Length: 229, dtype: int64

# %%
h_train['EnclosedPorch'].value_counts()
# Out:
# 0      878
# 112      9
# 96       5
# 216      4
# 252      3
#       ...
# 81       1
# 176      1
# 143      1
# 30       1
# 20       1
# Name: EnclosedPorch, Length: 100, dtype: int64

# %%
h_train['ScreenPorch'].value_counts()
# Out:
# 0      941
# 192      6
# 224      3
# 120      3
# 126      3
# 160      3
# 168      3
# 189      2
# 144      2
# 90       2
# 176      2
# 184      2
# 100      2
# 180      2
# 147      2
# 216      2
# 60       1
# 198      1
# 234      1
# 53       1
# 200      1
# 165      1
# 142      1
# 266      1
# 152      1
# 225      1
# 190      1
# 156      1
# 130      1
# 210      1
# 220      1
# 287      1
# 197      1
# 185      1
# 40       1
# 259      1
# 154      1
# 312      1
# 271      1
# 288      1
# 145      1
# 95       1
# 276      1
# 153      1
# 385      1
# 480      1
# 204      1
# 170      1
# 233      1
# 396      1
# 322      1
# 119      1
# 155      1
# 291      1
# 63       1
# 178      1
# 263      1
# 374      1
# Name: ScreenPorch, dtype: int64

# %%
h_train['BsmtFinSF2'].nunique()
# Out:
# 101

# %%
# remomve outliers from 95 to 100%. This value is taken so as to delete very high values.
lot_frontage_q = h_train["LotFrontage"].quantile(0.95)
h_train = h_train[h_train["LotFrontage"] < lot_frontage_q]

open_porch_sf_q = h_train["OpenPorchSF"].quantile(0.95)
h_train = h_train[h_train["OpenPorchSF"] < open_porch_sf_q]

gr_liv_area_q = h_train["GrLivArea"].quantile(0.95)
h_train = h_train[h_train["GrLivArea"] < gr_liv_area_q]

garage_area_q = h_train["GarageArea"].quantile(0.95)
h_train = h_train[h_train["GarageArea"] < garage_area_q]

bsmt_fin_sf2_q = h_train["BsmtFinSF2"].quantile(0.95)
h_train = h_train[h_train["BsmtFinSF2"] < bsmt_fin_sf2_q]

# %%
h_train=h_train.drop(['PoolArea','Id','3SsnPorch','LowQualFinSF','Utilities'], axis=1)

# %% [markdown]
# #### Observations: Outliers
# - Columns with outlier values are:
#   - LotFrontage
#   - OpenPorchSF
#   - GrLivArea
#   - GarageArea
#   - BsmtFinSF2
# - Outliers above 95% is removed.

# %% [markdown]
# #### 5.5. Feature Engineering<a class="anchor" id="section55"></a>
# - Derive values from existing values for adding value
# - Delete original variables

# %%
#DERIVED VARIABLES which might make more sense than year

h_train['Age'] = h_train['YrSold'] - h_train['YearBuilt']
h_train['Remod_Age'] = h_train['YrSold'] - h_train['YearRemodAdd']
h_train['Garage_Age'] = h_train['YrSold'] - h_train['GarageYrBlt']
h_train.drop(['YearBuilt','YearRemodAdd','GarageYrBlt','YrSold'],1, inplace = True)

# %% [markdown]
# #### Observations: Feature Engineering
# - Follwoing features were derived out of the existing variables
#   - Age(overall age of the house)  : Year sold - year built
#   - Remod_Age (Age of remodelling) : Year sold - YearRemodAdd
#   - Garage_Age (Age of garage)     : Year Sold - Year Garage Built

# %% [markdown]
# #### 5.6. Finding Correlation between Independent Variables<a class="anchor" id="section56"></a>
# - Use correlation function
# - Use heatmap for visualization
# - Threshold for significant correlation between independent variable is considered 75%

# %%
#Correlation
plt.figure(figsize=(20,16))
price_corr = h_train.corr()
sns.heatmap(price_corr,annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #### Observations: Correllation
# - No significant multicorrelation was observed with existing variables.

# %% [markdown]
# ### 6. Exploratory Data Analysis<a class="anchor" id="section6"></a>
# - Univariate Analysis
# - Bivariate Analysis

# %%
h_train.shape
# Out:
# (786, 70)

# %% [markdown]
# #### 6.1 Analysis of traget variable: Sale Price<a class="anchor" id="section61"></a>

# %%
from scipy.stats import norm
sns.distplot(h_train['SalePrice'], fit = norm)
plt.show()

# %% [markdown]
# ##### Observation
# - Sale price distribution is not normal as there are some houses at higher prices and is slightly skewed positively.
# - This could be expected as house prices may vary as per factors like location, size etc.

# %% [markdown]
# #### 6.2. Univariate Analysis<a class="anchor" id="section62"></a>
# - Analysis done using histplot.
# - Mostly the distribution is analysed.

# %%
f, ax = plt.subplots(2,3, figsize=(20,15))

sns.histplot(data=h_train, x="SalePrice", palette ='rainbow', kde=True, ax=ax[0,0])
sns.histplot(data=h_train, x="LotArea", palette ='rainbow', kde=True, ax=ax[1,0])
sns.histplot(data=h_train, x="BsmtFinSF1", palette ='rainbow', kde=True, ax=ax[0,1])
sns.histplot(data=h_train, x="1stFlrSF", palette ='rainbow', kde=True, ax=ax[1,1])
sns.histplot(data=h_train, x="2ndFlrSF", palette ='rainbow', kde=True, ax=ax[0,2])
sns.histplot(data=h_train, x="GrLivArea", palette ='rainbow', kde=True, ax=ax[1,2])

# %% [markdown]
# #### Observations: Univariate Analysis
# - Most of the data is not unifromally distributed.
# - Lot Area is highly skewed with most of the data in less than 20000 region
# - This is similar for most of the variables

# %% [markdown]
# #### 6.3. Bivariate Analysis<a class="anchor" id="section63"></a>

# %% [markdown]
# #### 6.3.1 Bivariate Analysis: Numerical Variables<a class="anchor" id="section631"></a>

# %%
# Segregating numerical colums
num_d = h_train.select_dtypes(include = ['float64', 'int64'])
num_d.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', 'ScreenPorch', 'MiscVal', 'MoSold', 'SalePrice', 'Age',
#        'Remod_Age', 'Garage_Age'],
#       dtype='object')

# %%
pair_p('LotFrontage', 'LotArea', 'OverallQual', 'OverallCond')

# %%
pair_p('MasVnrArea','BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF')

# %%
pair_p('TotalBsmtSF', '1stFlrSF',
       '2ndFlrSF', 'GrLivArea')

# %%
pair_p('BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath')

# %%
pair_p('BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces')

# %%
pair_p('GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF')

# %%
pair_p('EnclosedPorch', 'ScreenPorch', 'MiscVal', 'MoSold')

# %%
pair_p('Age',
       'Remod_Age', 'Garage_Age','SalePrice')

# %% [markdown]
# #### Observations: Bivariate Analysis of numerical variables
# - Clear linear negative corellation between sale price and age of building, remodelling age and grage age.
# - Month in which propert was sold does not have significant reltionship with sale price
# - Garage Area and number of garages have positive linear correlation
# - Having 2 firplaces increases the base price above those with no fireplace
# - Living Area, basmemnet area, 1st floor area and 2nd floor area has high positive corelation to sale price.
# - Lot area does have some influence on price.
# - Overall condition and quality hassignigicant impact on sale price.

# %% [markdown]
# #### 6.3.2 Bivariate Analysis: Categorical Variables<a class="anchor" id="section632"></a>

# %%
# Segregating categorical Columns
cat_d=h_train.select_dtypes(include='object')
cat_d.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'Street', 'LotShape', 'LandContour',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
cat_chart('MSZoning', 'Street', False)
cat_chart('LotShape', 'LandContour', False)

# %%
cat_chart('LotConfig', 'LandSlope',True)
cat_chart('Condition1', 'Condition2', True)

# %%
cat_chart('BldgType', 'HouseStyle', True)
cat_chart('RoofStyle', 'RoofMatl', True)

# %%
cat_chart('Exterior1st','Exterior2nd',True)
cat_chart('MasVnrType', 'ExterQual', True)

# %%
cat_chart('ExterCond', 'Foundation', True)
cat_chart('BsmtQual', 'BsmtCond', False)

# %%
cat_chart('BsmtFinType1', 'BsmtFinType2', True)
cat_chart('Heating', 'HeatingQC', False)

# %%
cat_chart('CentralAir', 'Electrical', True)
cat_chart('KitchenQual','Functional', True)

# %%
cat_chart('GarageQual', 'GarageCond', True)
cat_chart('GarageType', 'GarageFinish', True)

# %%
cat_chart('PavedDrive', 'BsmtExposure', False)
cat_chart('SaleType', 'SaleCondition', True)

# %% [markdown]
# ##### Observation: Bivariate analysis of categorical variables
# - Residential Low Density has maximum quantity of sale.
# - Normal Sale condition has signifatly more number of sales.
# - Conventional warranty deed commands most numbbers but warranty deed-cash commands more price.
# - Garage Qaulity does not affect prices much.
# - Excellent kitchen quality does impact price.
# - Heating quality and central air conditioning impact price.

# %% [markdown]
# ### 7. Model Creation<a class="anchor" id="section7"></a>

# %% [markdown]
# #### 7.1 Seperating X and y of train data<a class="anchor" id="section71"></a>

# %%
# Create X and y
y_train = h_train.pop('SalePrice') # Create a series for y_train
X_train_1 = h_train # pop will remove 'total_user' inplace from df_train and leave us with X_train
print('Shape of y_train :',y_train.shape)
print('Shape of X_train :',X_train_1.shape)
X_train_1.head(2)
# Out:
# Shape of y_train : (786,)
# Shape of X_train : (786, 69)
#      MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 104          50       RM         69.0     7758   Pave      Reg         Lvl
# 1185         50       RL         60.0     9738   Pave      Reg         Lvl
#
#      LotConfig LandSlope Neighborhood  ... OpenPorchSF EnclosedPorch  \
# 104     Corner       Gtl       IDOTRR  ...           0             0
# 1185    Inside       Gtl      Edwards  ...           0           236
#
#      ScreenPorch MiscVal  MoSold  SaleType SaleCondition Age Remod_Age  \
# 104          184       0       6        WD        Normal  76        57
# 1185           0       0       3        WD        Normal  82        56
#
#      Garage_Age
# 104        56.0
# 1185       41.0
#
# [2 rows x 69 columns]

# %% [markdown]
# #### 7.2. Scaling of Numeric Variables<a class="anchor" id="section72"></a>
# - Use minmax scalar
# - Minmax scalar reduces oulier influence by bringning all values between -1 to +1
# - Both fit and transform carried out
# - Test data will be transformed using same scalar

# %%
# Defining the Scalar and doing fit_transform
minmax=MinMax()
num_train = X_train_1.select_dtypes(exclude=['object'])
num_train.columns
X_train_1[num_train.columns] = minmax.fit_transform(X_train_1[num_train.columns])

# %%
# Segregating numerical columns for scaling
num_train.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', 'ScreenPorch', 'MiscVal', 'MoSold', 'Age', 'Remod_Age',
#        'Garage_Age'],
#       dtype='object')

# %%
# Checking the effect of scaling
X_train_1.head(3)
# Out:
#      MSSubClass MSZoning  LotFrontage   LotArea Street LotShape LandContour  \
# 104          50       RM     0.585366  0.039874   Pave      Reg         Lvl
# 1185         50       RL     0.475610  0.052443   Pave      Reg         Lvl
# 786          50       RM     0.475610  0.059185   Pave      Reg         Lvl
#
#      LotConfig LandSlope Neighborhood  ... OpenPorchSF EnclosedPorch  \
# 104     Corner       Gtl       IDOTRR  ...         0.0      0.000000
# 1185    Inside       Gtl      Edwards  ...         0.0      0.715152
# 786     Inside       Gtl      OldTown  ...         0.0      0.593939
#
#      ScreenPorch   MiscVal    MoSold  SaleType SaleCondition       Age  \
# 104     0.464646  0.000000  0.454545        WD        Normal  0.562963
# 1185    0.000000  0.000000  0.181818        WD        Normal  0.607407
# 786     0.000000  0.077419  0.454545        WD        Normal  0.703704
#
#      Remod_Age Garage_Age
# 104   0.950000   0.565657
# 1185  0.933333   0.414141
# ...

# %% [markdown]
# #### 7.3. Create Dummy Variables<a class="anchor" id="section73"></a>

# %%
str_train = X_train_1.select_dtypes(include=['object'])
str_train
X_train = pd.get_dummies(X_train_1, columns = (str_train.columns), drop_first = True)
X_train.head()
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  MasVnrArea  BsmtFinSF1  \
# 104      0.585366  0.039874        0.750        0.375      0.3750    0.136087
# 1185     0.475610  0.052443        0.500        0.750      0.0000    0.238153
# 786      0.475610  0.059185        0.500        0.625      0.0000    0.416768
# 379      0.475610  0.042191        0.625        0.500      0.0100    0.000000
# 1129     0.475610  0.036331        0.500        0.500      0.1125    0.568651
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  ...  SaleType_ConLI  \
# 104          0.0   0.407592     0.492891  0.489035  ...               0
# 1185         0.0   0.195804     0.371564  0.337171  ...               0
# 786          0.0   0.000000     0.325118  0.346491  ...               0
# 379          0.0   0.490509     0.465403  0.368969  ...               0
# 1129         0.0   0.000000     0.443602  0.330044  ...               0
#
# ...

# %% [markdown]
# #### 7.4. Recursive Feature Elimination - 1<a class="anchor" id="section74"></a>
# - Using RFE to initally select 75 features which are most significant out of 227 features.

# %%
# Running RFE with the output number of the variable equal to 15 (50% of Columns)
lr_rfe = LinearRegression()
lr_rfe.fit(X_train, y_train)

rfe = RFE(estimator=lr_rfe, n_features_to_select=75) 
rfe = rfe.fit(X_train, y_train)

# %%
# Selecting 75 most significant columns
cols = X_train.columns[rfe.support_]
cols
# Out:
# Index(['LotArea', 'OverallQual', 'OverallCond', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'BedroomAbvGr',
#        'GarageCars', 'ScreenPorch', 'Age', 'MSSubClass_90', 'MSZoning_FV',
#        'MSZoning_RH', 'MSZoning_RL', 'MSZoning_RM', 'LotShape_IR3',
#        'LandSlope_Sev', 'Neighborhood_Crawfor', 'Neighborhood_NoRidge',
#        'Neighborhood_NridgHt', 'Neighborhood_Somerst', 'Neighborhood_StoneBr',
#        'Condition1_PosA', 'Condition2_RRAn', 'Condition2_RRNn',
#        'BldgType_Duplex', 'BldgType_Twnhs', 'BldgType_TwnhsE',
#        'HouseStyle_2.5Unf', 'RoofStyle_Gable', 'RoofStyle_Gambrel',
#        'RoofStyle_Hip', 'RoofStyle_Mansard', 'RoofStyle_Shed',
#        'RoofMatl_Metal', 'RoofMatl_Tar&Grv', 'RoofMatl_WdShake',
#        'Exterior1st_AsphShn', 'Exterior1st_BrkFace', 'Exterior1st_CemntBd',
#        'Exterior2nd_CmentBd', 'Exterior2nd_Other', 'MasVnrType_BrkFace',
# ...

# %%
# Creating training set with slelcted columns
# Call the new training set as X_train_1
# Last number will vary with each iteration of modeling
X_train_1 = X_train[cols]
X_train_1.head(2)
# Out:
#        LotArea  OverallQual  OverallCond  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 104   0.039874         0.75        0.375    0.136087         0.0   0.407592
# 1185  0.052443         0.50        0.750    0.238153         0.0   0.195804
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  BedroomAbvGr  ...  GarageQual_Gd  \
# 104      0.492891  0.489035  0.414856      0.666667  ...              0
# 1185     0.371564  0.337171  0.190610      0.666667  ...              0
#
#       GarageQual_Po  GarageQual_TA  GarageCond_Fa  GarageCond_Gd  \
# 104               0              1              0              0
# 1185              0              1              0              0
#
#       GarageCond_Po  GarageCond_TA  SaleType_CWD  SaleType_Con  SaleType_ConLI
# 104               0              1             0             0               0
# 1185              0              1             0             0               0
#
# [2 rows x 75 columns]

# %% [markdown]
# #### 7.5. Create Models<a class="anchor" id="section75"></a>

# %% [markdown]
# 7.5.1 Model - 1<a class="anchor" id="section751"></a>
# - Maodel Name lr_sm_1 (Linear Regression using statsmodel number 1)
# - Data : X_train_1

# %%
# Adding coefficient to the existing columns
X_train_1_const = sm.add_constant(X_train_1)
# Create the 
lr_sm_1 = sm.OLS(y_train, X_train_1_const).fit()

# %%
# Summary of the model
lr_sm_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     117.4
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):               0.00
# Time:                        02:46:59   Log-Likelihood:                -8711.6
# No. Observations:                 786   AIC:                         1.757e+04
# Df Residuals:                     715   BIC:                         1.790e+04
# Df Model:                          70
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Check for the VIF values of the feature variables. 
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_1_const.columns
vif['VIF'] = [variance_inflation_factor(X_train_1_const.values, i) for i in range(X_train_1_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features   VIF
# 38        RoofMatl_Metal   inf
# 26       Condition1_PosA   inf
# 71         GarageCond_Po   inf
# 70         GarageCond_Gd   inf
# 69         GarageCond_Fa   inf
# ..                   ...   ...
# 22  Neighborhood_NoRidge  1.06
# 19          LotShape_IR3  1.05
# 75        SaleType_ConLI  1.04
# 52       Foundation_Wood  1.03
# 0                  const  0.00
#
# [76 rows x 2 columns]

# %% [markdown]
# 7.5.2 Model - 2<a class="anchor" id="section752"></a>
#   - Model Name: lr_sm_2
#   - Data :      X_train_2

# %%
# Dropping highly correlated variables and insignificant variables
# Variable dropped: BsmtFinSF2 ; coreelation : inf
X_train_2 = X_train_1.drop('BsmtFinSF2', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train_2_const = sm.add_constant(X_train_2)
# Fit the model
lr_sm_2 = sm.OLS(y_train, X_train_2_const).fit()

# %%
# Model Summary
lr_sm_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     117.4
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):               0.00
# Time:                        02:47:00   Log-Likelihood:                -8711.6
# No. Observations:                 786   AIC:                         1.757e+04
# Df Residuals:                     715   BIC:                         1.790e+04
# Df Model:                          70
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_2_const.columns
vif['VIF'] = [variance_inflation_factor(X_train_2_const.values, i) for i in range(X_train_2_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features   VIF
# 37        RoofMatl_Metal   inf
# 25       Condition1_PosA   inf
# 70         GarageCond_Po   inf
# 69         GarageCond_Gd   inf
# 68         GarageCond_Fa   inf
# ..                   ...   ...
# 21  Neighborhood_NoRidge  1.06
# 18          LotShape_IR3  1.05
# 74        SaleType_ConLI  1.04
# 51       Foundation_Wood  1.03
# 0                  const  0.00
#
# [75 rows x 2 columns]

# %% [markdown]
# 7.5.3. Model - 3<a class="anchor" id="section753"></a>
# - Model: lr_sm_3
# - Data: X_train_3
# - Variable dropped: RoofMatl_Metal
# - VIF Score: Inf

# %%
# Dropping highly correlated variables and insignificant variables
X_train_3 = X_train_2.drop('RoofMatl_Metal', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train_3_const = sm.add_constant(X_train_3)
# Create the 
lr_sm_3 = sm.OLS(y_train, X_train_3_const).fit()

# %%
lr_sm_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     117.4
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):               0.00
# Time:                        02:47:01   Log-Likelihood:                -8711.6
# No. Observations:                 786   AIC:                         1.757e+04
# Df Residuals:                     715   BIC:                         1.790e+04
# Df Model:                          70
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_3_const.columns
vif['VIF'] = [variance_inflation_factor(X_train_3_const.values, i) for i in range(X_train_3_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features   VIF
# 36        RoofStyle_Shed   inf
# 70         GarageCond_TA   inf
# 69         GarageCond_Po   inf
# 38      RoofMatl_WdShake   inf
# 28       BldgType_Duplex   inf
# ..                   ...   ...
# 72          SaleType_Con  1.07
# 21  Neighborhood_NoRidge  1.06
# 18          LotShape_IR3  1.05
# 73        SaleType_ConLI  1.04
# 50       Foundation_Wood  1.03
#
# [74 rows x 2 columns]

# %% [markdown]
# 7.5.4 Model - 4<a class="anchor" id="section754"></a>
# - Model: lr_sm_4
# - Data: X_train_4
# - Variable dropped: RoofMatl_WdShake
# - VIF Score: Inf

# %%
# Dropping highly correlated variables and insignificant variables
X_train_4 = X_train_3.drop('RoofMatl_WdShake', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train_4_const = sm.add_constant(X_train_4)
# Fit the model
lr_sm_4 = sm.OLS(y_train, X_train_4_const).fit()

# %%
lr_sm_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     117.4
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):               0.00
# Time:                        02:47:02   Log-Likelihood:                -8711.6
# No. Observations:                 786   AIC:                         1.757e+04
# Df Residuals:                     715   BIC:                         1.790e+04
# Df Model:                          70
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_4_const.columns
vif['VIF'] = [variance_inflation_factor(X_train_4_const.values, i) for i in range(X_train_4_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features   VIF
# 62         GarageQual_Fa   inf
# 68         GarageCond_Po   inf
# 28       BldgType_Duplex   inf
# 69         GarageCond_TA   inf
# 63         GarageQual_Gd   inf
# ..                   ...   ...
# 26       Condition2_RRAn  1.07
# 21  Neighborhood_NoRidge  1.06
# 18          LotShape_IR3  1.05
# 72        SaleType_ConLI  1.04
# 49       Foundation_Wood  1.03
#
# [73 rows x 2 columns]

# %% [markdown]
# #### 7.6. Recursive Feauture Elimination - 2<a class="anchor" id="section76"></a>
# - Number of varaible with VIF value as infinity is quiet large.
# - Hence, variables are reduced to 45.

# %%
# Running RFE with the output number of the variable equal to 15 (50% of Columns)
lr_rfe_1 = LinearRegression()
lr_rfe_1.fit(X_train, y_train)

rfe_1 = RFE(estimator=lr_rfe_1, n_features_to_select=40) 
rfe_1 = rfe_1.fit(X_train, y_train)

# %%
# Getting the 45 most significant variables names
cols_1 = X_train.columns[rfe_1.support_]
cols_1
# Out:
# Index(['LotArea', 'OverallQual', 'OverallCond', 'BsmtFinSF1', 'TotalBsmtSF',
#        '1stFlrSF', '2ndFlrSF', 'BedroomAbvGr', 'GarageCars', 'ScreenPorch',
#        'Age', 'MSZoning_RH', 'MSZoning_RL', 'MSZoning_RM', 'LandSlope_Sev',
#        'Neighborhood_Crawfor', 'Neighborhood_NoRidge', 'Neighborhood_Somerst',
#        'Condition1_PosA', 'Condition2_RRAn', 'RoofStyle_Gable',
#        'RoofStyle_Gambrel', 'RoofStyle_Hip', 'RoofStyle_Mansard',
#        'RoofStyle_Shed', 'RoofMatl_Metal', 'RoofMatl_Tar&Grv',
#        'Exterior2nd_Other', 'ExterQual_Fa', 'ExterQual_Gd', 'ExterQual_TA',
#        'Foundation_Wood', 'BsmtQual_Fa', 'BsmtQual_Gd', 'BsmtQual_TA',
#        'BsmtCond_Po', 'KitchenQual_Fa', 'KitchenQual_TA', 'SaleType_CWD',
#        'SaleType_Con'],
#       dtype='object')

# %%
# Creating new X_train using 45 significant variables
X_train2_1 = X_train[cols_1]
X_train2_1.head(2)
# Out:
#        LotArea  OverallQual  OverallCond  BsmtFinSF1  TotalBsmtSF  1stFlrSF  \
# 104   0.039874         0.75        0.375    0.136087     0.492891  0.489035
# 1185  0.052443         0.50        0.750    0.238153     0.371564  0.337171
#
#       2ndFlrSF  BedroomAbvGr  GarageCars  ScreenPorch  ...  ExterQual_TA  \
# 104   0.414856      0.666667        0.25     0.464646  ...             1
# 1185  0.190610      0.666667        0.25     0.000000  ...             1
#
#       Foundation_Wood  BsmtQual_Fa  BsmtQual_Gd  BsmtQual_TA  BsmtCond_Po  \
# 104                 0            0            0            1            0
# 1185                0            0            0            1            0
#
#       KitchenQual_Fa  KitchenQual_TA  SaleType_CWD  SaleType_Con
# 104                0               1             0             0
# 1185               0               1             0             0
#
# [2 rows x 40 columns]

# %% [markdown]
# 7.6.1. Model - 5<a class="anchor" id="section761"></a>
# - Model: lr_sm2_1
# - Data: X_train2_1

# %%
# Adding coefficient to the existing columns
X_train2_1_const = sm.add_constant(X_train2_1)
# Fit the model 
lr_sm2_1 = sm.OLS(y_train, X_train2_1_const).fit()

# %%
# Model Summary
lr_sm2_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     171.2
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):               0.00
# Time:                        02:47:06   Log-Likelihood:                -8801.0
# No. Observations:                 786   AIC:                         1.768e+04
# Df Residuals:                     746   BIC:                         1.787e+04
# Df Model:                          39
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Check for the VIF values of the feature variables. 

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train2_1_const.columns
vif['VIF'] = [variance_inflation_factor(X_train2_1_const.values, i) for i in range(X_train2_1_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features    VIF
# 27      RoofMatl_Tar&Grv    inf
# 26        RoofMatl_Metal    inf
# 25        RoofStyle_Shed    inf
# 24     RoofStyle_Mansard    inf
# 23         RoofStyle_Hip    inf
# 22     RoofStyle_Gambrel    inf
# 21       RoofStyle_Gable    inf
# 31          ExterQual_TA  21.78
# 30          ExterQual_Gd  18.56
# 13           MSZoning_RL  16.54
# 14           MSZoning_RM  13.54
# 35           BsmtQual_TA  13.35
# 34           BsmtQual_Gd  10.48
# 18  Neighborhood_Somerst   4.37
# 11                   Age   3.78
# 2            OverallQual   3.26
# 6               1stFlrSF   3.24
# 5            TotalBsmtSF   3.08
# 7               2ndFlrSF   2.83
# 33           BsmtQual_Fa   2.73
# 15         LandSlope_Sev   2.46
# 29          ExterQual_Fa   2.35
# 38        KitchenQual_TA   2.32
# 12           MSZoning_RH   2.28
# 8           BedroomAbvGr   1.90
# 1                LotArea   1.84
# 9             GarageCars   1.74
# 37        KitchenQual_Fa   1.53
# ...

# %% [markdown]
# 7.6.2 Model - 6<a class="anchor" id="section762"></a>
# - Model: lr_sm2_2
# - Data: X_train2_2
# - Variable dropped: RoofMatl_WdShake
# - VIF Score: Inf

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_2 = X_train2_1.drop('RoofStyle_Shed', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_2_const = sm.add_constant(X_train2_2)
# Fit the model
lr_sm2_2 = sm.OLS(y_train, X_train2_2_const).fit()

# %%
# Model Summary
lr_sm2_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     171.2
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):               0.00
# Time:                        02:47:06   Log-Likelihood:                -8801.0
# No. Observations:                 786   AIC:                         1.768e+04
# Df Residuals:                     746   BIC:                         1.787e+04
# Df Model:                          39
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train2_2_const.columns
vif['VIF'] = [variance_inflation_factor(X_train2_2_const.values, i) for i in range(X_train2_2_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features      VIF
# 0                  const  1220.44
# 21       RoofStyle_Gable   148.87
# 23         RoofStyle_Hip   133.83
# 30          ExterQual_TA    21.78
# 29          ExterQual_Gd    18.56
# 13           MSZoning_RL    16.54
# 14           MSZoning_RM    13.54
# 34           BsmtQual_TA    13.35
# 22     RoofStyle_Gambrel    12.25
# 33           BsmtQual_Gd    10.48
# 26      RoofMatl_Tar&Grv     6.95
# 24     RoofStyle_Mansard     6.36
# 18  Neighborhood_Somerst     4.37
# 11                   Age     3.78
# 2            OverallQual     3.26
# 6               1stFlrSF     3.24
# 5            TotalBsmtSF     3.08
# 7               2ndFlrSF     2.83
# 32           BsmtQual_Fa     2.73
# 15         LandSlope_Sev     2.46
# 28          ExterQual_Fa     2.35
# 37        KitchenQual_TA     2.32
# 12           MSZoning_RH     2.28
# 25        RoofMatl_Metal     2.02
# 8           BedroomAbvGr     1.90
# 1                LotArea     1.84
# ...

# %% [markdown]
# 7.6.3 Model - 7<a class="anchor" id="section763"></a>
# - Model: lr_sm2_3
# - Data: X_train2_3
# - Variable dropped: RoofStyle_Gable
# - VIF Score:148.47

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_3 = X_train2_2.drop('RoofStyle_Gable', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_3_const = sm.add_constant(X_train2_3)
# Create the 
lr_sm2_3 = sm.OLS(y_train, X_train2_3_const).fit()

# %%
lr_sm2_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.893
# Method:                 Least Squares   F-statistic:                     173.2
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):               0.00
# Time:                        02:47:07   Log-Likelihood:                -8806.6
# No. Observations:                 786   AIC:                         1.769e+04
# Df Residuals:                     747   BIC:                         1.787e+04
# Df Model:                          38
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train2_3_const.columns
vif['VIF'] = [variance_inflation_factor(X_train2_3_const.values, i) for i in range(X_train2_3_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features     VIF
# 0                  const  241.62
# 29          ExterQual_TA   21.78
# 28          ExterQual_Gd   18.56
# 13           MSZoning_RL   16.54
# 14           MSZoning_RM   13.54
# 33           BsmtQual_TA   13.35
# 32           BsmtQual_Gd   10.48
# 18  Neighborhood_Somerst    4.37
# 11                   Age    3.77
# 2            OverallQual    3.26
# 6               1stFlrSF    3.24
# 5            TotalBsmtSF    3.08
# 7               2ndFlrSF    2.83
# 31           BsmtQual_Fa    2.73
# 27          ExterQual_Fa    2.35
# 36        KitchenQual_TA    2.32
# 12           MSZoning_RH    2.27
# 15         LandSlope_Sev    2.05
# 8           BedroomAbvGr    1.88
# 1                LotArea    1.77
# 9             GarageCars    1.74
# 35        KitchenQual_Fa    1.52
# 4             BsmtFinSF1    1.48
# 34           BsmtCond_Po    1.44
# 19       Condition1_PosA    1.40
# 23     RoofStyle_Mansard    1.37
# 3            OverallCond    1.36
# ...

# %% [markdown]
# 7.6.4 Model - 8<a class="anchor" id="section764"></a>
# - Model: lr_sm2_4
# - Data: X_train2_4
# - Variable dropped: ExterQual_TA
# - VIF Score: 21.78

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_4 = X_train2_3.drop('ExterQual_TA', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_4_const = sm.add_constant(X_train2_4)
# Fit the model
lr_sm2_4 = sm.OLS(y_train, X_train2_4_const).fit()

# %%
# Model Summary
lr_sm2_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.889
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     161.5
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):               0.00
# Time:                        02:47:07   Log-Likelihood:                -8840.8
# No. Observations:                 786   AIC:                         1.776e+04
# Df Residuals:                     748   BIC:                         1.794e+04
# Df Model:                          37
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train2_4_const.columns
vif['VIF'] = [variance_inflation_factor(X_train2_4_const.values, i) for i in range(X_train2_4_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features     VIF
# 0                  const  198.26
# 13           MSZoning_RL   16.50
# 14           MSZoning_RM   13.52
# 32           BsmtQual_TA   10.72
# 31           BsmtQual_Gd    8.00
# 18  Neighborhood_Somerst    4.37
# 11                   Age    3.76
# 6               1stFlrSF    3.23
# 2            OverallQual    3.22
# 5            TotalBsmtSF    3.07
# 7               2ndFlrSF    2.81
# 30           BsmtQual_Fa    2.46
# 28          ExterQual_Gd    2.33
# 35        KitchenQual_TA    2.30
# 12           MSZoning_RH    2.27
# 15         LandSlope_Sev    2.05
# 8           BedroomAbvGr    1.86
# 1                LotArea    1.77
# 9             GarageCars    1.74
# 34        KitchenQual_Fa    1.52
# 4             BsmtFinSF1    1.48
# 33           BsmtCond_Po    1.44
# 19       Condition1_PosA    1.40
# 23     RoofStyle_Mansard    1.37
# 3            OverallCond    1.36
# 27          ExterQual_Fa    1.34
# 22         RoofStyle_Hip    1.23
# ...

# %% [markdown]
# 7.6.5 Model - 9<a class="anchor" id="section765"></a>
# - Model: lr_sm2_5
# - Data: X_train2_5
# - Variable dropped: MSZoning_RL
# - VIF Score: 16.50

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_5 = X_train2_4.drop('MSZoning_RL', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_5_const = sm.add_constant(X_train2_5)
# Fit the model
lr_sm2_5 = sm.OLS(y_train, X_train2_5_const).fit()

# %%
# Model Summary
lr_sm2_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     161.6
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):               0.00
# Time:                        02:47:07   Log-Likelihood:                -8850.7
# No. Observations:                 786   AIC:                         1.778e+04
# Df Residuals:                     749   BIC:                         1.795e+04
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train2_5_const.columns
vif['VIF'] = [variance_inflation_factor(X_train2_5_const.values, i) for i in range(X_train2_5_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features     VIF
# 0                  const  128.25
# 31           BsmtQual_TA   10.72
# 30           BsmtQual_Gd    8.00
# 11                   Age    3.75
# 2            OverallQual    3.22
# 6               1stFlrSF    3.22
# 5            TotalBsmtSF    3.07
# 7               2ndFlrSF    2.81
# 29           BsmtQual_Fa    2.46
# 27          ExterQual_Gd    2.33
# 34        KitchenQual_TA    2.30
# 14         LandSlope_Sev    2.05
# 8           BedroomAbvGr    1.84
# 1                LotArea    1.77
# 9             GarageCars    1.74
# 33        KitchenQual_Fa    1.52
# 4             BsmtFinSF1    1.48
# 32           BsmtCond_Po    1.44
# 18       Condition1_PosA    1.40
# 13           MSZoning_RM    1.38
# 22     RoofStyle_Mansard    1.37
# 3            OverallCond    1.35
# 26          ExterQual_Fa    1.33
# 21         RoofStyle_Hip    1.23
# 23        RoofMatl_Metal    1.20
# 17  Neighborhood_Somerst    1.20
# 15  Neighborhood_Crawfor    1.15
# ...

# %% [markdown]
# 7.6.6 Model - 10<a class="anchor" id="section766"></a>
# - Model: lr_sm2_5
# - Data: X_train2_5
# - Variable dropped: BsmtQual_TA
# - VIF Score: 10.72

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_6 = X_train2_5.drop('BsmtQual_TA', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_6_const = sm.add_constant(X_train2_6)
# Fit the model
lr_sm2_6 = sm.OLS(y_train, X_train2_6_const).fit()

# %%
# Model Summary
lr_sm2_6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     139.2
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):          4.52e-301
# Time:                        02:47:07   Log-Likelihood:                -8912.4
# No. Observations:                 786   AIC:                         1.790e+04
# Df Residuals:                     750   BIC:                         1.806e+04
# Df Model:                          35
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train2_6_const.columns
vif['VIF'] = [variance_inflation_factor(X_train2_6_const.values, i) for i in range(X_train2_6_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features    VIF
# 0                  const  91.07
# 11                   Age   3.49
# 6               1stFlrSF   3.21
# 5            TotalBsmtSF   3.06
# 2            OverallQual   3.01
# 7               2ndFlrSF   2.81
# 27          ExterQual_Gd   2.29
# 33        KitchenQual_TA   2.27
# 14         LandSlope_Sev   2.04
# 30           BsmtQual_Gd   1.99
# 8           BedroomAbvGr   1.81
# 1                LotArea   1.76
# 9             GarageCars   1.74
# 32        KitchenQual_Fa   1.52
# 4             BsmtFinSF1   1.48
# 31           BsmtCond_Po   1.44
# 18       Condition1_PosA   1.40
# 13           MSZoning_RM   1.37
# 22     RoofStyle_Mansard   1.37
# 3            OverallCond   1.34
# 26          ExterQual_Fa   1.33
# 21         RoofStyle_Hip   1.23
# 29           BsmtQual_Fa   1.20
# 17  Neighborhood_Somerst   1.20
# 23        RoofMatl_Metal   1.20
# 15  Neighborhood_Crawfor   1.15
# 10           ScreenPorch   1.13
# 20     RoofStyle_Gambrel   1.07
# ...

# %% [markdown]
# ##### Removing insignificat variables

# %% [markdown]
# 7.6.7 Model - 11<a class="anchor" id="section2"767</a>
# - All VIF Score are within acceptable parametes
# - Model: lr_sm2_7
# - Data: X_train2_7
# - Variable dropped: ExterQual_Fa

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_7 = X_train2_6.drop('ExterQual_Fa', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_7_const = sm.add_constant(X_train2_7)
# Create the 
lr_sm2_7 = sm.OLS(y_train, X_train2_7_const).fit()

# %%
lr_sm2_7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     143.4
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):          3.75e-302
# Time:                        02:47:08   Log-Likelihood:                -8912.4
# No. Observations:                 786   AIC:                         1.789e+04
# Df Residuals:                     751   BIC:                         1.806e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train2_7_const.columns
vif['VIF'] = [variance_inflation_factor(X_train2_7_const.values, i) for i in range(X_train2_7_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features    VIF
# 0                  const  88.90
# 11                   Age   3.49
# 6               1stFlrSF   3.21
# 5            TotalBsmtSF   3.06
# 2            OverallQual   3.00
# 7               2ndFlrSF   2.81
# 26          ExterQual_Gd   2.29
# 32        KitchenQual_TA   2.27
# 14         LandSlope_Sev   2.04
# 29           BsmtQual_Gd   1.98
# 8           BedroomAbvGr   1.80
# 1                LotArea   1.76
# 9             GarageCars   1.74
# 4             BsmtFinSF1   1.47
# 31        KitchenQual_Fa   1.45
# 18       Condition1_PosA   1.40
# 13           MSZoning_RM   1.37
# 22     RoofStyle_Mansard   1.37
# 30           BsmtCond_Po   1.34
# 3            OverallCond   1.32
# 21         RoofStyle_Hip   1.21
# 28           BsmtQual_Fa   1.20
# 23        RoofMatl_Metal   1.20
# 17  Neighborhood_Somerst   1.20
# 15  Neighborhood_Crawfor   1.15
# 10           ScreenPorch   1.13
# 20     RoofStyle_Gambrel   1.07
# 24      RoofMatl_Tar&Grv   1.06
# ...

# %% [markdown]
# 7.6.8. Model - 12<a class="anchor" id="section768"></a>
# - Model: lr_sm2_8
# - Data: X_train2_8
# - Variable dropped: RoofStyle_Hip

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_8 = X_train2_7.drop('RoofStyle_Hip', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_8_const = sm.add_constant(X_train2_8)
# Fit the model
lr_sm2_8 = sm.OLS(y_train, X_train2_8_const).fit()

# %%
lr_sm2_8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     148.0
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):          3.07e-303
# Time:                        02:47:08   Log-Likelihood:                -8912.4
# No. Observations:                 786   AIC:                         1.789e+04
# Df Residuals:                     752   BIC:                         1.805e+04
# Df Model:                          33
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train2_8_const.columns
vif['VIF'] = [variance_inflation_factor(X_train2_8_const.values, i) for i in range(X_train2_8_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features    VIF
# 0                  const  88.82
# 11                   Age   3.47
# 6               1stFlrSF   3.15
# 5            TotalBsmtSF   3.05
# 2            OverallQual   2.97
# 7               2ndFlrSF   2.81
# 25          ExterQual_Gd   2.28
# 31        KitchenQual_TA   2.26
# 14         LandSlope_Sev   2.04
# 28           BsmtQual_Gd   1.86
# 8           BedroomAbvGr   1.80
# 1                LotArea   1.76
# 9             GarageCars   1.73
# 4             BsmtFinSF1   1.47
# 30        KitchenQual_Fa   1.45
# 18       Condition1_PosA   1.40
# 21     RoofStyle_Mansard   1.37
# 13           MSZoning_RM   1.36
# 29           BsmtCond_Po   1.34
# 3            OverallCond   1.32
# 22        RoofMatl_Metal   1.20
# 17  Neighborhood_Somerst   1.20
# 27           BsmtQual_Fa   1.19
# 15  Neighborhood_Crawfor   1.14
# 10           ScreenPorch   1.13
# 20     RoofStyle_Gambrel   1.07
# 23      RoofMatl_Tar&Grv   1.06
# 16  Neighborhood_NoRidge   1.05
# ...

# %% [markdown]
# 7.6.9 Model - 13<a class="anchor" id="section769"></a>
# - Model: lr_sm2_9
# - Data: X_train2_9
# - Variable dropped: RoofStyle_Gambrel

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_9 = X_train2_8.drop('RoofStyle_Gambrel', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_9_const = sm.add_constant(X_train2_9)
# Create the 
lr_sm2_9 = sm.OLS(y_train, X_train2_9_const).fit()

# %%
lr_sm2_9.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     152.8
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):          2.75e-304
# Time:                        02:47:08   Log-Likelihood:                -8912.5
# No. Observations:                 786   AIC:                         1.789e+04
# Df Residuals:                     753   BIC:                         1.804e+04
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train2_9_const.columns
vif['VIF'] = [variance_inflation_factor(X_train2_9_const.values, i) for i in range(X_train2_9_const.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features    VIF
# 0                  const  88.80
# 11                   Age   3.46
# 6               1stFlrSF   3.15
# 5            TotalBsmtSF   3.05
# 2            OverallQual   2.96
# 7               2ndFlrSF   2.79
# 24          ExterQual_Gd   2.28
# 30        KitchenQual_TA   2.25
# 14         LandSlope_Sev   2.04
# 27           BsmtQual_Gd   1.86
# 8           BedroomAbvGr   1.80
# 1                LotArea   1.76
# 9             GarageCars   1.73
# 4             BsmtFinSF1   1.47
# 29        KitchenQual_Fa   1.44
# 18       Condition1_PosA   1.40
# 20     RoofStyle_Mansard   1.37
# 13           MSZoning_RM   1.36
# 28           BsmtCond_Po   1.34
# 3            OverallCond   1.32
# 17  Neighborhood_Somerst   1.20
# 21        RoofMatl_Metal   1.20
# 26           BsmtQual_Fa   1.19
# 15  Neighborhood_Crawfor   1.14
# 10           ScreenPorch   1.13
# 22      RoofMatl_Tar&Grv   1.06
# 31          SaleType_CWD   1.05
# 16  Neighborhood_NoRidge   1.05
# ...

# %% [markdown]
# 7.6.10. Model - 14<a class="anchor" id="section7610"></a>
# - All VIF Score are within acceptable parametes
# - Model: lr_sm2_10
# - Data: X_train2_10
# - Variable dropped: MSZoning_RH

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_10 = X_train2_9.drop('MSZoning_RH', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_10_const = sm.add_constant(X_train2_10)
# Create the 
lr_sm2_10 = sm.OLS(y_train, X_train2_10_const).fit()

# %%
lr_sm2_10.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     157.9
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):          2.38e-305
# Time:                        02:47:09   Log-Likelihood:                -8912.6
# No. Observations:                 786   AIC:                         1.789e+04
# Df Residuals:                     754   BIC:                         1.804e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 7.6.11 Model - 15<a class="anchor" id="section7611"></a>
# - All VIF Score are within acceptable parametes
# - Model: lr_sm2_10
# - Data: X_train2_10
# - Variable dropped: RoofStyle_Mansard

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_11 = X_train2_10.drop('RoofStyle_Mansard', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_11_const = sm.add_constant(X_train2_11)
# Create the 
lr_sm2_11 = sm.OLS(y_train, X_train2_11_const).fit()

# %%
lr_sm2_11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     163.3
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):          2.13e-306
# Time:                        02:47:09   Log-Likelihood:                -8912.7
# No. Observations:                 786   AIC:                         1.789e+04
# Df Residuals:                     755   BIC:                         1.803e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 7.6.12. Model - 16<a class="anchor" id="section7612"></a>
# - All VIF Score are within acceptable parametes
# - Model: lr_sm2_12
# - Data: X_train2_12
# - Variable dropped: KitchenQual_Fa

# %%
# Dropping highly correlated variables and insignificant variables
X_train2_12 = X_train2_11.drop('KitchenQual_Fa', axis = 1)

# %%
# Adding coefficient to the existing columns
X_train2_12_const = sm.add_constant(X_train2_12)
# Create the 
lr_sm2_12 = sm.OLS(y_train, X_train2_12_const).fit()

# %%
lr_sm2_12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     169.0
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):          2.00e-307
# Time:                        02:47:09   Log-Likelihood:                -8913.0
# No. Observations:                 786   AIC:                         1.789e+04
# Df Residuals:                     756   BIC:                         1.803e+04
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### 7.8. Ridge and Lasso Regression<a class="anchor" id="section78"></a>

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %% [markdown]
# ##### 7.8.1 Ridge Regression
# - Use Grid Search Cross Validation
# - 5 fold validation
# - Hyperparameter tunig of alpha values

# %%
#RIDGE REGULARIZATION

# list of alphas to tune


params = {'alpha': [0.0001, 0.001, 0.005,0.05,0.10,0.008]}


ridge = Ridge()

# cross validation
folds = 5
model_ridge = GridSearchCV(estimator = ridge, 
                        param_grid = params, 
                        scoring= 'neg_mean_absolute_error', 
                        cv = folds, 
                        return_train_score=True,
                        verbose = 1)            
model_ridge.fit(X_train2_12, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.0001, 0.001, 0.005, 0.05, 0.1, 0.008]},
#              return_train_score=True, scoring='neg_mean_absolute_error',
#              verbose=1)

# %%
print(model_ridge.best_params_)
print(model_ridge.best_score_)
ridge_best_param = model_ridge.best_params_
# Out:
# {'alpha': 0.1}
# -15706.56024468337

# %%
ridge_results = pd.DataFrame(model_ridge.cv_results_)
ridge_results = ridge_results[ridge_results['param_alpha']<=100]
ridge_results.head(2)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.004875      0.000716         0.002760        0.000221      0.0001
# 1       0.003969      0.000088         0.002489        0.000045       0.001
#
#               params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'alpha': 0.0001}      -16871.570735      -14908.561222      -18253.759641
# 1   {'alpha': 0.001}      -16871.440301      -14906.563131      -18247.229559
#
#    split3_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0      -14117.606381  ...    -15836.700158     1508.469209                6
# 1      -14117.465446  ...    -15834.744940     1506.741740                5
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 0       -14178.621086       -14678.655069       -14551.228290
# 1       -14178.919953       -14678.892781       -14551.267205
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# ...

# %%
# plotting mean test and train scoes with alpha 
ridge_results['param_alpha'] = ridge_results['param_alpha'].astype('int32')
plt.figure(figsize=(16,5))

# plotting
plt.plot(ridge_results['param_alpha'], ridge_results['mean_train_score'])
plt.plot(ridge_results['param_alpha'], ridge_results['mean_test_score'])
plt.xlabel('alpha')
plt.ylabel('Negative Mean Absolute Error')
plt.title("Negative Mean Absolute Error and alpha")
plt.legend(['train score', 'test score'], loc='upper right')
plt.show()

# %% [markdown]
# #### 7.8.1.1 Fitting Ridge using best lambda value<a class="anchor" id="section7811"></a>

# %%
alpha = .1
ridge = Ridge(alpha=alpha)

ridge.fit(X_train2_12, y_train)
ridge.coef_
# Out:
# array([126854.87161264,  89368.09506501,  43119.8279164 ,  30761.70568215,
#         42820.80171964, 110916.72507213,  76017.98242698, -35760.49204193,
#         22118.01352102,  16361.76681726, -70269.36242031,  -6364.22450657,
#        -28246.12948575,  22899.00747132,  18322.47619847,   7644.56222984,
#        -13021.16150133, -36008.42188225,  32655.06086104,  -6461.37811352,
#         33369.21286797,  -1414.63319496, -18990.40803332,  11197.70515625,
#         -8866.3607779 ,  35870.09123063, -10923.06548411,  32913.92989702,
#         35213.94351729])

# %% [markdown]
# #### 7.8.1.2. Predicting Traget Value on Train Data<a class="anchor" id="section7812"></a>

# %%
y_train_pred = ridge.predict(X_train2_12)
print(metrics.r2_score(y_true=y_train, y_pred=y_train_pred))
# Out:
# 0.8658482496874149

# %% [markdown]
# #### 7.8.2. Lasso Regression<a class="anchor" id="section782"></a>
# - Use Grid Search Cross Validation
# - Hyperparameter tuning of alpha values

# %%
#lasso
params = {'alpha': [0.005, 0.01, 0.001, 0.05, 0.0001]}
lasso = Lasso()

# cross validation
model_lasso = GridSearchCV(estimator = lasso, 
                        param_grid = params, 
                        scoring= 'neg_mean_absolute_error', 
                        cv = folds, 
                        return_train_score=True,
                        verbose = 1)            

model_lasso.fit(X_train2_12, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.005, 0.01, 0.001, 0.05, 0.0001]},
#              return_train_score=True, scoring='neg_mean_absolute_error',
#              verbose=1)

# %%
print(model_lasso.best_params_)
print(model_lasso.best_score_)
lasso_best_param = model_lasso.best_params_
# Out:
# {'alpha': 0.05}
# -15836.540747756628

# %%
lasso_results = pd.DataFrame(model_ridge.cv_results_)
lasso_results = ridge_results[ridge_results['param_alpha']<=100]
lasso_results.head(2)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0       0.004875      0.000716         0.002760        0.000221            0
# 1       0.003969      0.000088         0.002489        0.000045            0
#
#               params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'alpha': 0.0001}      -16871.570735      -14908.561222      -18253.759641
# 1   {'alpha': 0.001}      -16871.440301      -14906.563131      -18247.229559
#
#    split3_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0      -14117.606381  ...    -15836.700158     1508.469209                6
# 1      -14117.465446  ...    -15834.744940     1506.741740                5
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 0       -14178.621086       -14678.655069       -14551.228290
# 1       -14178.919953       -14678.892781       -14551.267205
#
# ...

# %%
# plotting mean test and train scoes with alpha 
lasso_results['param_alpha'] = lasso_results['param_alpha'].astype('int32')
plt.figure(figsize=(16,5))

# plotting
plt.plot(lasso_results['param_alpha'], lasso_results['mean_train_score'])
plt.plot(lasso_results['param_alpha'], lasso_results['mean_test_score'])
plt.xlabel('alpha')
plt.ylabel('Negative Mean Absolute Error')
plt.title("Negative Mean Absolute Error and alpha")
plt.legend(['train score', 'test score'], loc='upper right')
plt.show()

# %% [markdown]
# ##### 7.8.2.1 Fit Lasso Model using Best Lambda Value<a class="anchor" id="section7821"></a>

# %%
alpha = 0.05

lasso = Lasso(alpha=alpha)
        
lasso.fit(X_train2_12, y_train)
# Out:
# Lasso(alpha=0.1)

# %% [markdown]
# ##### 7.8.2.2. Predict Target Value on Train Data<a class="anchor" id="section7822"></a>

# %%
y_train_pred_lasso = lasso.predict(X_train2_12)
print(metrics.r2_score(y_true=y_train, y_pred=y_train_pred_lasso))
# Out:
# 0.8663658268633818

# %% [markdown]
# ### 8. Prepare Test Data<a class="anchor" id="section8"></a>
# - Test data will now be prepared to match with train data
# - The steps followed will be same as the steps taken to arraive at final train data set.

# %%
h_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438 entries, 503 to 116
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             438 non-null    int64
#  1   MSSubClass     438 non-null    int64
#  2   MSZoning       438 non-null    object
#  3   LotFrontage    354 non-null    float64
#  4   LotArea        438 non-null    int64
#  5   Street         438 non-null    object
#  6   Alley          23 non-null     object
#  7   LotShape       438 non-null    object
#  8   LandContour    438 non-null    object
#  9   Utilities      438 non-null    object
#  10  LotConfig      438 non-null    object
#  11  LandSlope      438 non-null    object
#  12  Neighborhood   438 non-null    object
#  13  Condition1     438 non-null    object
#  14  Condition2     438 non-null    object
#  15  BldgType       438 non-null    object
#  16  HouseStyle     438 non-null    object
# ...

# %%
# Removing missing values as in train set
missing_data(h_test)
# Out:
#               Total    Percent
# LotFrontage    84.0  19.178082
# Alley         415.0  94.748858
# MasVnrType      2.0   0.456621
# MasVnrArea      2.0   0.456621
# BsmtQual       11.0   2.511416
# BsmtCond       11.0   2.511416
# BsmtExposure   11.0   2.511416
# BsmtFinType1   11.0   2.511416
# BsmtFinType2   12.0   2.739726
# FireplaceQu   193.0  44.063927
# GarageType     23.0   5.251142
# GarageYrBlt    23.0   5.251142
# GarageFinish   23.0   5.251142
# GarageQual     23.0   5.251142
# GarageCond     23.0   5.251142
# PoolQC        433.0  98.858447
# Fence         358.0  81.735160
# MiscFeature   427.0  97.488584

# %%
# Deleting variables as in train data
h_test.drop(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], axis = 1, inplace=True)

# %%
# Impute values as done in train set using smae function and rules
impute_values(h_test)
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
# ['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']

# %%
# Checking for unique values
h_test.nunique().sort_values()
# Out:
# Utilities         1
# CentralAir        2
# KitchenAbvGr      2
# BsmtHalfBath      2
# Street            2
#                ...
# BsmtUnfSF       323
# 1stFlrSF        352
# GrLivArea       358
# LotArea         381
# Id              438
# Length: 76, dtype: int64

# %%
# Dealing with data types in lines wtih train set
h_test['MSSubClass'] = h_test['MSSubClass'].astype('str')

# %%
# Dropping redundant variables
h_test=h_test.drop(['PoolArea','Id','3SsnPorch','LowQualFinSF','Utilities'], axis=1)

# %%
#DERIVED VARIABLES which might make more sense than year

h_test['Age'] = h_test['YrSold'] - h_test['YearBuilt']
h_test['Remod_Age'] = h_test['YrSold'] - h_test['YearRemodAdd']
h_test['Garage_Age'] = h_test['YrSold'] - h_test['GarageYrBlt']
h_test.drop(['YearBuilt','YearRemodAdd','GarageYrBlt','YrSold'],1, inplace = True)

# %%
# Create X and y
y_test = h_test.pop('SalePrice') # Create a series for y_train
X_test = h_test # pop will remove 'total_user' inplace from df_train and leave us with X_train
print('Shape of y_test :',y_test.shape)
print('Shape of X_test :',X_test.shape)
X_test.head(2)
# Out:
# Shape of y_test : (438,)
# Shape of X_test : (438, 69)
#     MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 503         20       RL        100.0    15602   Pave      IR1         Lvl
# 101         60       RL         77.0     9206   Pave      Reg         Lvl
#
#     LotConfig LandSlope Neighborhood  ... OpenPorchSF EnclosedPorch  \
# 503    Inside       Gtl      Crawfor  ...          54             0
# 101    Inside       Gtl      SawyerW  ...          46             0
#
#     ScreenPorch MiscVal  MoSold  SaleType SaleCondition Age Remod_Age  \
# 503         161       0       3        WD        Normal  51        13
# 101           0       0       6        WD        Normal  25        25
#
#     Garage_Age
# 503       51.0
# 101       25.0
#
# [2 rows x 69 columns]

# %%
# Scaling numerical variables using minmax scalar which was used earlier
num_test = X_test.select_dtypes(exclude=['object'])
num_test.columns
X_test[num_test.columns] = minmax.transform(X_test[num_test.columns])

# %%
num_test.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', 'ScreenPorch', 'MiscVal', 'MoSold', 'Age', 'Remod_Age',
#        'Garage_Age'],
#       dtype='object')

# %%
# Creating dummy variables
# A differece of 12 columns owing to variation in values of the variables is found
# This variation needs to be addressed
str_test = X_test.select_dtypes(include=['object'])
str_test
X_test = pd.get_dummies(X_test, columns = (str_test.columns), drop_first = True)
X_test.head()
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  MasVnrArea  BsmtFinSF1  \
# 503      0.963415  0.089669        0.750        0.875        0.00    0.757594
# 101      0.682927  0.049066        0.625        0.500        0.21    0.000000
# 608      0.695122  0.067869        0.875        0.625        0.00    0.260024
# 1089     0.195122  0.011674        0.875        0.500        0.00    0.631227
# 819      0.280488  0.031068        0.750        0.500        0.08    0.445322
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  ...  PavedDrive_Y  \
# 503          0.0   0.126873     0.711374  0.804276  ...             1
# 101          0.0   0.370130     0.351185  0.352522  ...             1
# 608          0.0   0.268232     0.457346  0.880482  ...             1
# 1089         0.0   0.103896     0.590995  0.500548  ...             1
# 819          0.0   0.312188     0.643602  0.561404  ...             1
#
#       SaleType_ConLD  SaleType_New  SaleType_Oth  SaleType_WD  \
# ...

# %% [markdown]
# #### 8.1. Adjusting difference in Variable Count<a class="anchor" id="section81"></a>
# - Post creation of dummy variables, 12 variabels are missing in test data.
# - This is due to difference in value within the variable columns
# - Find these variables.
# - Create the missing variable columns in test data and use '0' to fill the values.

# %%
# Adding missing colums to test daummy data
# Get missing columns in the training test
# 
missing_cols = set( X_train.columns ) - set( X_test.columns )
missing_cols
# Add a missing column in test set with default value equal to 0
for c in missing_cols:
  X_test[c] = 0
# Ensure the order of column in the test set is in the same order than in train set
X_test = X_test[X_train.columns]

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (786, 227)
# (438, 227)

# %%
X_test_1 = X_test[cols_1]

# %%
# Dropping highly correlated variables and insignificant variables
X_test_1 = X_test_1.drop(['RoofStyle_Shed','RoofStyle_Gable','ExterQual_TA','MSZoning_RL',
                          'BsmtQual_TA','ExterQual_Fa','RoofStyle_Hip','RoofStyle_Gambrel','MSZoning_RH','RoofStyle_Mansard','KitchenQual_Fa'], axis = 1)

# %% [markdown]
# ### 9. Model Evaluation<a class="anchor" id="section9"></a>
# - Use R 2 score for evaluation of models.

# %%
# Predict using Ridge 
y_test_pred_ridge = ridge.predict(X_test_1)
print(metrics.r2_score(y_true=y_test, y_pred=y_test_pred_ridge))
# Out:
# 0.6696900872618732

# %%
# Predict using Lambda
y_test_pred_lasso = lasso.predict(X_test_1)
print(metrics.r2_score(y_true=y_test, y_pred=y_test_pred_lasso))
# Out:
# 0.6644787437385544

# %% [markdown]
# ### 10. Conclusion<a class="anchor" id="section10"></a>

# %% [markdown]
# #### 10.1 Summary<a class="anchor" id="section101"></a>
# - The variables that affect the pricing most are:
#   - Lot Area
#   - GrLivArea
#   - Grage Area
#   - Age of House
#   - Age of remodelling
#   - Overal condition of house
#   - Number of baths
#   - Porch Area
# - Model Selection
#   - Both Ridge and Lasso models seems to underfit.
#   - Accuracy of models:
#     - Train Data
#       - Ridge: 86.6
#       - Lasso: 86.6
#     - Test Data
#       - Ridge: 66.51
#       - Lasso: 66.48
#
# - Selcted Model: **Ridge with alpha = .1**

# %% [markdown]
# #### 10.2. Recommendation<a class="anchor" id="section102"></a>
# - Of the models created, Ridge Regression model with aplha = .1 shows better performance.
# - Further models using different algorithms may be created to gain better accuracy.

# %% [markdown]
# #### 10.3. Acknowledgement<a class="anchor" id="section103"></a>
# - I express my sinciere gratitude to the insturctors, student buddy and support team at UpGrad and IIIT-B for the knowledge imparted.
# - I am grateful to the contributors in Kaggle, stackoverflow and numerous other platforms who helped me compelete the project.
